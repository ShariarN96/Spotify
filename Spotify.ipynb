# %%
#Importing libraries

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df= pd.read_csv(r'spotify-2023.csv',encoding='ISO-8859-1')

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability', 'valence', 'energy', 'acousticness',
#        'instrumentalness', 'liveness', 'speechiness'],
#       dtype='object')

# %%
df.columns=df.columns.to_series().apply(lambda x: x.replace('_%',''))

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability', 'valence', 'energy', 'acousticness',
#        'instrumentalness', 'liveness', 'speechiness'],
#       dtype='object')

# %%
df['artist(s)_name'].value_counts().to_frame()
# Out:
#                            count
# artist(s)_name
# Taylor Swift                  34
# The Weeknd                    22
# Bad Bunny                     19
# SZA                           19
# Harry Styles                  17
# ...                          ...
# Karol G, Ovy On The Drums      1
# Coolio, L.V.                   1
# Kordhell                       1
# Kenia OS                       1
# Feid, Sech, Jhayco             1
#
# [645 rows x 1 columns]

# %%
Top_artists=df['artist(s)_name'].value_counts().to_frame().head(10).reset_index()
Top_artists
# Out:
#    artist(s)_name  count
# 0    Taylor Swift     34
# 1      The Weeknd     22
# 2       Bad Bunny     19
# 3             SZA     19
# 4    Harry Styles     17
# 5  Kendrick Lamar     12
# 6   Morgan Wallen     11
# 7      Ed Sheeran      9
# 8             BTS      8
# 9            Feid      8

# %%
sns.barplot(x='count', y='artist(s)_name',data=Top_artists)
plt.show()

# %%
df.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability             int64
# valence                  int64
# energy                   int64
# acousticness             int64
# instrumentalness         int64
# liveness                 int64
# speechiness              int64
# dtype: object

# %%
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# %%
plt.figure(figsize=(12, 8))
ax=sns.barplot(x=top_streams['streams'], y=top_streams['track_name'], palette='RdBu')
plt.xlabel('Streams (in billions)')
plt.ylabel('Track Name')
plt.title('Top 20 Songs with Most Streams on Spotify')
plt.xticks(rotation=90)
plt.show()

# %%
top_streams
# Out:
#                                         track_name  \
# 574            Love Grows (Where My Rosemary Goes)
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
#
#                    artist(s)_name       streams
# 574             Edison Lighthouse  1.105376e+13
# 55                     The Weeknd  3.703895e+09
# 179                    Ed Sheeran  3.562544e+09
# 86                  Lewis Capaldi  2.887242e+09
# 620                   Tones and I  2.864792e+09
# 41          Post Malone, Swae Lee  2.808097e+09
# 162           Drake, WizKid, Kyla  2.713922e+09
# ...

# %%
average_artist_count = df['artist_count'].mean()
threshold = 1
solo_songs = df[df['artist_count'] <= threshold]
collaboration_tracks = df[df['artist_count'] > threshold]

plt.figure(figsize=(7, 6))
plt.bar(['Solo', 'Collaboration'], [len(solo_songs), len(collaboration_tracks)], color=['blueviolet', 'lightskyblue'])
plt.xlabel('Track Type')
plt.ylabel('Number of Tracks')
plt.title('Distribution of Solo and Collaboration Tracks')
#plt.grid(axis='y', linestyle='--', alpha=0.7)
#plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Distribution of Solo and Collaboration Tracks')

# %%
df['instrumentalness'].unique()
# Out:
# array([ 0, 63, 17,  2, 19,  1, 18,  3, 51,  8,  9,  4,  5, 25, 46, 10, 90,
#        47, 35, 12, 13, 41, 24, 23,  6, 20, 30, 15, 91, 27, 72, 42, 14, 44,
#        11, 61, 83, 22, 33], dtype=int64)

# %%
df[['streams','track_name','artist(s)_name']].sort_values(by='streams', ascending=False)
# Out:
#           streams                                     track_name  \
# 55   3.703895e+09                                Blinding Lights
# 179  3.562544e+09                                   Shape of You
# 86   2.887242e+09                              Someone You Loved
# 620  2.864792e+09                                   Dance Monkey
# 41   2.808097e+09  Sunflower - Spider-Man: Into the Spider-Verse
# ..            ...                                            ...
# 142  1.195664e+07                    Gol Bolinha, Gol Quadrado 2
# 144  1.159939e+07                                          QUEMA
# 393  1.365184e+06                              Jhoome Jo Pathaan
# 123  2.762000e+03                                    Que Vuelvas
# 574           NaN            Love Grows (Where My Rosemary Goes)
#
#                                         artist(s)_name
# 55                                          The Weeknd
# 179                                         Ed Sheeran
# ...

# %%
df[df['instrumentalness']==0]
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
#df[df['instrumentalness']== 0][['streams','track_name','artist(s)_name','instrumentalness']]

# %%
#df.loc[df['instrumentalness']!=0,['streams','track_name','artist(s)_name','instrumentalness']]

# %%
song_keys=df['key'].value_counts()
sns.barplot(x=song_keys.index, y=song_keys.values,palette='tab10')
# Out:
# <Axes: xlabel='key'>

# %%
mean_streams=df.groupby('key')['streams'].mean().sort_values(ascending=False)
sns.barplot(x=mean_streams.values, y=mean_streams.index)
# Out:
# <Axes: ylabel='key'>

# %%
stream_trend=df.groupby('released_year')['streams'].sum().tail(13)
plt.figure(figsize=(20, 6))
ax=sns.barplot(y=stream_trend.values, x=stream_trend.index)
ax.set_xlabel('Year',fontsize=20)
ax.set_ylabel('# of streams',fontsize=20)
ax.tick_params(labelsize=16)

# %%
df.groupby('artist(s)_name')['in_spotify_playlists'].mean().sort_values(ascending=False)
# Out:
# artist(s)_name
# Pharrell Williams, Nile Rodgers, Daft Punk    52898.0
# The Killers                                   51979.0
# a-ha                                          44927.0
# Drake, WizKid, Kyla                           43257.0
# Gotye, Kimbra                                 42798.0
#                                                ...
# RM, Colde                                       105.0
# Arijit Singh, Sachin-Jigar                       86.0
# Natanael Cano                                    86.0
# Shubh                                            67.0
# Jack Black                                       34.0
# Name: in_spotify_playlists, Length: 645, dtype: float64

# %%
df[[ 'artist(s)_name','track_name' ,'in_spotify_playlists']].sort_values(by='in_spotify_playlists', ascending=False).head(10)
# Out:
#                                  artist(s)_name  \
# 757  Pharrell Williams, Nile Rodgers, Daft Punk
# 630                                 The Killers
# 720                                      Avicii
# 624                                     Nirvana
# 199                                        a-ha
# 55                                   The Weeknd
# 162                         Drake, WizKid, Kyla
# 727                               Gotye, Kimbra
# 114                             Tears For Fears
# 871                               Guns N' Roses
#
#                                     track_name  in_spotify_playlists
# 757                     Get Lucky - Radio Edit                 52898
# 630                             Mr. Brightside                 51979
# 720                    Wake Me Up - Radio Edit                 50887
# 624  Smells Like Teen Spirit - Remastered 2021                 49991
# 199                                 Take On Me                 44927
# ...

# %%
df[['artist(s)_name', 'in_apple_playlists']].sort_values(by='in_apple_playlists', ascending=False).head(10)
# Out:
#                    artist(s)_name  in_apple_playlists
# 55                     The Weeknd                 672
# 403       Calvin Harris, Dua Lipa                 537
# 620                   Tones and I                 533
# 407                      Dua Lipa                 532
# 84   Justin Bieber, The Kid Laroi                 492
# 693  Shawn Mendes, Camila Cabello                 453
# 86                  Lewis Capaldi                 440
# 127                  Harry Styles                 437
# 162           Drake, WizKid, Kyla                 433
# 14                   Harry Styles                 403

# %%
df['track_name']
# Out:
# 0      Seven (feat. Latto) (Explicit Ver.)
# 1                                     LALA
# 2                                  vampire
# 3                             Cruel Summer
# 4                           WHERE SHE GOES
#                       ...
# 948                           My Mind & Me
# 949              Bigger Than The Whole Sky
# 950                   A Veces (feat. Feid)
# 951                          En La De Ella
# 952                                  Alone
# Name: track_name, Length: 953, dtype: object

# %%
best_spotify=df[[ 'artist(s)_name','track_name' ,'in_spotify_playlists','bpm','danceability','energy']].sort_values(by='in_spotify_playlists', ascending=False).head(10)

# %%
c=range(1, len(best_spotify)+1)

# %%
best_spotify
# Out:
#                                  artist(s)_name  \
# 757  Pharrell Williams, Nile Rodgers, Daft Punk
# 630                                 The Killers
# 720                                      Avicii
# 624                                     Nirvana
# 199                                        a-ha
# 55                                   The Weeknd
# 162                         Drake, WizKid, Kyla
# 727                               Gotye, Kimbra
# 114                             Tears For Fears
# 871                               Guns N' Roses
#
#                                     track_name  in_spotify_playlists  bpm  \
# 757                     Get Lucky - Radio Edit                 52898  116
# 630                             Mr. Brightside                 51979  148
# 720                    Wake Me Up - Radio Edit                 50887  124
# 624  Smells Like Teen Spirit - Remastered 2021                 49991  117
# ...

# %%
print((range(1,10)))
# Out:
# range(1, 10)

# %%
df['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %%
df.groupby('mode')['streams'].mean()
# Out:
# mode
# Major    5.348328e+08
# Minor    4.859445e+08
# Name: streams, dtype: float64

# %%
import seaborn as sns
selected_features = df[['bpm', 'danceability', 'valence', 'energy', 'acousticness', 'instrumentalness', 'liveness', 'speechiness']]
correlation_matrix = selected_features.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Between Audio Features')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['danceability'], bins=30, kde=True)
plt.xlabel('Danceability')
plt.ylabel('Frequency')
plt.title('Distribution of Danceability')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_['energy'], bins=30, kde=True, color='lightcoral')
plt.xlabel('Energy')
plt.ylabel('Frequency')
plt.title('Distribution of Energy')
plt.grid(True)
plt.show()

# %%
df.hist(column=df.columns, 
              color='purple', # many options, some to consider are
                            # ['aqua', 'red', 'gold', 'royalblue', 
                            #'darkorange', 'green', 'purple', 
                            #'steelblue', 'yellow', 'lime', 'magenta']
              #edgecolor='black', # color of the edge line for the bars
              figsize=(20,20), #(x axis and y axis in inches)
              bins=10, # number of bins to divide the data into
              rwidth=0.9, # width between each bin
              grid=False # to remove the grid for cleaner visualization
             )
plt.show()

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability', 'valence', 'energy', 'acousticness',
#        'instrumentalness', 'liveness', 'speechiness'],
#       dtype='object')

# %%
ax = df['mode'].value_counts().plot(kind='barh', figsize=(10,2), grid=False,color=['crimson', 'dodgerblue'])
ax.bar_label(ax.containers[0], label_type='center', color='white', weight='bold')
plt.title('Spotify Track Modes')
plt.yticks([0,1],['Major', 'Minor'])
plt.xlabel('Track Counts')
plt.show()
